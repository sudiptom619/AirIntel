# %%
from features.engineer_features import compute_ndvi_features, folium_ndvi_map
g = compute_ndvi_features()
m = folium_ndvi_map(g)
m  # Jupyter will render the folium map
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/pt/w89bshms67l17_1bw7strp340000gn/T/ipykernel_61666/3725577704.py in ?()
#       1 from features.engineer_features import compute_ndvi_features, folium_ndvi_map
#       2 g = compute_ndvi_features()
# ----> 3 m = folium_ndvi_map(g)
#       4 m  # Jupyter will render the folium map
#
# ~/Desktop/AirIntel/features/engineer_features.py in ?(grid, center, zoom_start)
#     137     m = folium.Map(location=list(center), zoom_start=zoom_start)
#     138
#     139     # Use the reset index (named 'index') as the join key in feature properties
#     140     # key_on='feature.properties.index' will match the 'index' property created by reset_index()
# --> 141     folium.Choropleth(
#     142         geo_data=grid_wgs.__geo_interface__,
#     143         name="NDVI",
#     144         data=grid_wgs,
#
# ~/Desktop/AirIntel/.venv/lib/python3.12/site-packages/folium/features.py in ?(self, geo_data, data, columns, key_on, bins, fill_color, nan_fill_color, fill_opacity, nan_fill_opacity, line_color, line_weight, line_opacity, name, legend_name, overlay, control, show, topojson, smooth_factor, highlight, use_jenks, **kwargs)
#    1573         # Create color_data dict
#    1574         if hasattr(data, "set_index"):
#    1575             # This is a pd.DataFrame
#    1576             assert columns is not None
# -> 1577             color_data = data.set_index(columns[0])[columns[1]].to_dict()  # type: ignore
#    1578         elif hasattr(data, "to_dict"):
#    1579             # This is a pd.Series
#    1580             color_data = data.to_dict()  # type: ignore
#
# ~/Desktop/AirIntel/.venv/lib/python3.12/site-packages/pandas/core/frame.py in ?(self, keys, drop, append, inplace, verify_integrity)
#    6140                     if not found:
#    6141                         missing.append(col)
#    6142
#    6143         if missing:
# -> 6144             raise KeyError(f"None of {missing} are in the columns")
#    6145
#    6146         if inplace:
#    6147             frame = self
#
# KeyError: "None of ['index'] are in the columns"
